# %% [markdown]
# In this notebook different files from previous notebooks and ones downloaded separately are loaded, preprocessed and joined so that final analysis could be done on them.

# %%
import pandas as pd 
import numpy as np 
import re
from pandasql import sqldf

# %% [markdown]
# df_articles: contains the information for each article extracted from wikimedia
#
# df_ores: contains the prediction for each article and its rev_id
#
# df_population: contains the population estimates for 2022 for each state
#
# df_states: contains the region wise division of each state

# %%
df_articles = pd.read_csv('page_record.csv')
df_ores = pd.read_csv('ores_predictions.csv')
df_population = pd.read_excel('NST-EST2022-POP.xlsx')
df_states = pd.read_excel('US States by Region - US Census Bureau.xlsx')

# %% [markdown]
# Preprocessing the population record dataframe. Primarily to correct the columns name issue as can be seen below and secondly there was a . before some names of states. So I removed those as we will be joining on these in future.

# %%
df_population.head()
# Out:
#   table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0                                    Geographic Area
# 1                                      United States
# 2                                          Northeast
# 3                                            Midwest
# 4                                              South
#
#                      Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0  April 1, 2020 Estimates Base        2020        2021        2022
# 1                     331449520   331511512   332031554   333287557
# 2                      57609156    57448898    57259257    57040406
# 3                      68985537    68961043    68836505    68787595
# 4                     126266262   126450613   127346029   128716192

# %%
# Set the first row as column names
df_population.columns = df_population.iloc[0]

# Drop the first row (which is now used as column names)
df_population = df_population[1:]

# Reset the index (optional)
df_population.reset_index(drop=True, inplace=True)

# Display the DataFrame
df_population.tail()
# Out:
# 0  Geographic Area April 1, 2020 Estimates Base     2020     2021     2022
# 52     .Washington                      7705247  7724031  7740745  7785786
# 53  .West Virginia                      1793755  1791420  1785526  1775156
# 54      .Wisconsin                      5893725  5896271  5880101  5892539
# 55        .Wyoming                       576837   577605   579483   581381
# 56    .Puerto Rico                      3285874  3281557  3262693  3221789

# %%
# Remove dots from the values in column 'A'
df_population['Geographic Area'] = df_population['Geographic Area'].str.replace('.', '', regex=False)

# Display the modified DataFrame
df_population.head()
# Out:
# 0 Geographic Area April 1, 2020 Estimates Base       2020       2021  \
# 0   United States                    331449520  331511512  332031554
# 1       Northeast                     57609156   57448898   57259257
# 2         Midwest                     68985537   68961043   68836505
# 3           South                    126266262  126450613  127346029
# 4            West                     78588565   78650958   78589763
#
# 0       2022
# 0  333287557
# 1   57040406
# 2   68787595
# 3  128716192
# 4   78743364

# %%
df_population[df_population['Geographic Area'] == 'Alabama'][0:8]
# Out:
# 0 Geographic Area April 1, 2020 Estimates Base     2020     2021     2022
# 5         Alabama                      5024356  5031362  5049846  5074296

# %% [markdown]
# Preprocessing the articles dataframe to separate the cities and states. A regex expression is written to ensure that state has an exact state and any entries before the state are just entered into the city column

# %%
df_articles.head()
# Out:
#    Unnamed: 0  pageid  ns                title contentmodel pagelanguage  \
# 0           0  104730   0   Abbeville, Alabama     wikitext           en
# 1           1  104761   0  Adamsville, Alabama     wikitext           en
# 2           2  105188   0     Addison, Alabama     wikitext           en
# 3           3  104726   0       Akron, Alabama     wikitext           en
# 4           4  105109   0   Alabaster, Alabama     wikitext           en
#
#   pagelanguagehtmlcode pagelanguagedir               touched   lastrevid  \
# 0                   en             ltr  2023-10-10T22:35:37Z  1171163550
# 1                   en             ltr  2023-10-10T22:35:37Z  1177621427
# 2                   en             ltr  2023-10-10T22:35:37Z  1168359898
# 3                   en             ltr  2023-10-10T22:35:37Z  1165909508
# 4                   en             ltr  2023-10-10T22:35:37Z  1179139816
#
#    length    talkid                                            fullurl  \
# 0   24706  281244.0   https://en.wikipedia.org/wiki/Abbeville,_Alabama
# 1   18040  281272.0  https://en.wikipedia.org/wiki/Adamsville,_Alabama
# 2   13309  281517.0     https://en.wikipedia.org/wiki/Addison,_Alabama
# 3   11710  281240.0       https://en.wikipedia.org/wiki/Akron,_Alabama
# 4   20343  281444.0   https://en.wikipedia.org/wiki/Alabaster,_Alabama
#
#                                              editurl  \
# 0  https://en.wikipedia.org/w/index.php?title=Abb...
# 1  https://en.wikipedia.org/w/index.php?title=Ada...
# 2  https://en.wikipedia.org/w/index.php?title=Add...
# 3  https://en.wikipedia.org/w/index.php?title=Akr...
# 4  https://en.wikipedia.org/w/index.php?title=Ala...
#
#                                         canonicalurl  watchers  redirect  new
# 0   https://en.wikipedia.org/wiki/Abbeville,_Alabama       NaN       NaN  NaN
# 1  https://en.wikipedia.org/wiki/Adamsville,_Alabama       NaN       NaN  NaN
# 2     https://en.wikipedia.org/wiki/Addison,_Alabama       NaN       NaN  NaN
# 3       https://en.wikipedia.org/wiki/Akron,_Alabama       NaN       NaN  NaN
# 4   https://en.wikipedia.org/wiki/Alabaster,_Alabama       NaN       NaN  NaN

# %%
# Extract city and state from the 'Location' column
df_articles['City'] = df_articles['title'].str.split(',').str[0]
df_articles['State'] = df_articles['title'].str.split(',').str[-1]

# %%
df_articles[['City', 'State']] = df_articles[['City', 'State']].applymap(lambda x: x.strip())

# %%
#checking that how many unique values are in the states column
df_articles['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Utqiaġvik', 'Arkansas',
#        'California', 'Los Angeles', 'San Diego', 'San Francisco',
#        '2010 United States census', '2020 United States census',
#        'Colorado', 'Denver', 'Delaware', 'Florida',
#        'County (United States)', 'Miami', 'Georgia', 'Atlanta',
#        'Echols County', 'Hawaii', 'Kauai', 'Idaho', 'Illinois', 'Indiana',
#        'Indianapolis', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'New Orleans', 'Maine', 'Maryland', 'Massachusetts', 'Boston',
#        'Nantucket', 'Michigan', 'Detroit', 'Minnesota', 'Minneapolis',
#        'Mississippi', 'Missouri', 'St. Louis', 'Montana', 'New Hampshire',
#        'Nevada', 'Las Vegas', 'New Jersey', 'New Mexico', 'New York',
#        'Population', 'Square mile', 'New York City',
#        'American National Standards Institute',
#        'Federal Information Processing Standards',
#        'Geographic Names Information System', 'Syracuse',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oklahoma City', 'Oregon', 'Pennsylvania', 'Philadelphia',
#        'Pittsburgh', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Grand Divisions of Tennessee', 'Texas', 'Utah',
#        'Salt Lake City', 'Vermont', 'Wikipedia:Citation needed',
#        'Virginia', 'Washington', 'Seattle', 'West Virginia', 'Wisconsin',
#        'Milwaukee', 'Wyoming'], dtype=object)

# %% [markdown]
# df_articles and df_ores are joined on lastrevid and rev_id respectively and then a few columns are dropped. Rest all irrelevant columns will be dropped towards the end before saving the file.

# %%
join_1 = pd.merge(df_articles, df_ores, left_on=df_articles['lastrevid'],
                  right_on = df_ores['rev_id'], how='left')

# %%
join_1.columns
# Out:
# Index(['key_0', 'Unnamed: 0_x', 'pageid', 'ns', 'title', 'contentmodel',
#        'pagelanguage', 'pagelanguagehtmlcode', 'pagelanguagedir', 'touched',
#        'lastrevid', 'length', 'talkid', 'fullurl', 'editurl', 'canonicalurl',
#        'watchers', 'redirect', 'new', 'City', 'State', 'Unnamed: 0_y',
#        'rev_id', 'Prediction'],
#       dtype='object')

# %%
join_1.drop(['key_0', 'Unnamed: 0_x'], axis = 1, inplace = True)

# %%
join_1[0:20]
# Out:
#       pageid  ns                                 title contentmodel  \
# 0     104730   0                    Abbeville, Alabama     wikitext
# 1     104761   0                   Adamsville, Alabama     wikitext
# 2     105188   0                      Addison, Alabama     wikitext
# 3     104726   0                        Akron, Alabama     wikitext
# 4     105109   0                    Alabaster, Alabama     wikitext
# 5     104899   0                  Albertville, Alabama     wikitext
# 6     105153   0               Alexander City, Alabama     wikitext
# 7     105086   0                   Aliceville, Alabama     wikitext
# 8     100811   0                      Allgood, Alabama     wikitext
# 9     100812   0                      Altoona, Alabama     wikitext
# 10    104595   0                    Andalusia, Alabama     wikitext
# 11  46726043   0  Anderson, Lauderdale County, Alabama     wikitext
# 12    103733   0                     Anniston, Alabama     wikitext
# 13    104617   0                         Arab, Alabama     wikitext
# 14    104850   0                      Ardmore, Alabama     wikitext
# 15    104764   0                         Argo, Alabama     wikitext
# 16    104630   0                       Ariton, Alabama     wikitext
# 17    105189   0                        Arley, Alabama     wikitext
# 18    104734   0                      Ashford, Alabama     wikitext
# 19    104574   0                      Ashland, Alabama     wikitext
#
#    pagelanguage pagelanguagehtmlcode pagelanguagedir               touched  \
# 0            en                   en             ltr  2023-10-10T22:35:37Z
# 1            en                   en             ltr  2023-10-10T22:35:37Z
# 2            en                   en             ltr  2023-10-10T22:35:37Z
# 3            en                   en             ltr  2023-10-10T22:35:37Z
# 4            en                   en             ltr  2023-10-10T22:35:37Z
# 5            en                   en             ltr  2023-10-10T22:35:37Z
# 6            en                   en             ltr  2023-10-10T22:35:37Z
# 7            en                   en             ltr  2023-10-10T22:35:37Z
# 8            en                   en             ltr  2023-10-10T22:35:35Z
# 9            en                   en             ltr  2023-10-10T22:35:35Z
# 10           en                   en             ltr  2023-10-10T22:35:36Z
# 11           en                   en             ltr  2023-09-16T14:34:48Z
# 12           en                   en             ltr  2023-10-10T22:35:36Z
# 13           en                   en             ltr  2023-10-10T22:35:36Z
# 14           en                   en             ltr  2023-10-10T22:35:37Z
# 15           en                   en             ltr  2023-10-10T22:35:37Z
# 16           en                   en             ltr  2023-10-10T22:35:36Z
# 17           en                   en             ltr  2023-10-10T22:35:37Z
# 18           en                   en             ltr  2023-10-10T22:35:37Z
# 19           en                   en             ltr  2023-10-10T22:35:36Z
#
#      lastrevid  length  ...  \
# 0   1171163550   24706  ...
# 1   1177621427   18040  ...
# 2   1168359898   13309  ...
# 3   1165909508   11710  ...
# 4   1179139816   20343  ...
# 5   1179198677   26930  ...
# 6   1179140073   25275  ...
# 7   1167792390   31568  ...
# 8   1165909718   11278  ...
# 9   1165909823   10679  ...
# 10  1179141586   24744  ...
# 11   662691565      47  ...
# 12  1176049382   51647  ...
# 13  1171375371   16262  ...
# 14  1176903479   17332  ...
# 15  1177623964   11608  ...
# 16  1166014478   14652  ...
# 17  1166014498   12191  ...
# 18  1166014593   17847  ...
# 19  1174331705   17754  ...
#
#                                               editurl  \
# 0   https://en.wikipedia.org/w/index.php?title=Abb...
# 1   https://en.wikipedia.org/w/index.php?title=Ada...
# 2   https://en.wikipedia.org/w/index.php?title=Add...
# 3   https://en.wikipedia.org/w/index.php?title=Akr...
# 4   https://en.wikipedia.org/w/index.php?title=Ala...
# 5   https://en.wikipedia.org/w/index.php?title=Alb...
# 6   https://en.wikipedia.org/w/index.php?title=Ale...
# 7   https://en.wikipedia.org/w/index.php?title=Ali...
# 8   https://en.wikipedia.org/w/index.php?title=All...
# 9   https://en.wikipedia.org/w/index.php?title=Alt...
# 10  https://en.wikipedia.org/w/index.php?title=And...
# 11  https://en.wikipedia.org/w/index.php?title=And...
# 12  https://en.wikipedia.org/w/index.php?title=Ann...
# 13  https://en.wikipedia.org/w/index.php?title=Ara...
# 14  https://en.wikipedia.org/w/index.php?title=Ard...
# 15  https://en.wikipedia.org/w/index.php?title=Arg...
# 16  https://en.wikipedia.org/w/index.php?title=Ari...
# 17  https://en.wikipedia.org/w/index.php?title=Arl...
# 18  https://en.wikipedia.org/w/index.php?title=Ash...
# 19  https://en.wikipedia.org/w/index.php?title=Ash...
#
#                                          canonicalurl watchers redirect  new  \
# 0    https://en.wikipedia.org/wiki/Abbeville,_Alabama      NaN      NaN  NaN
# 1   https://en.wikipedia.org/wiki/Adamsville,_Alabama      NaN      NaN  NaN
# 2      https://en.wikipedia.org/wiki/Addison,_Alabama      NaN      NaN  NaN
# 3        https://en.wikipedia.org/wiki/Akron,_Alabama      NaN      NaN  NaN
# 4    https://en.wikipedia.org/wiki/Alabaster,_Alabama      NaN      NaN  NaN
# 5   https://en.wikipedia.org/wiki/Albertville,_Ala...     34.0      NaN  NaN
# 6   https://en.wikipedia.org/wiki/Alexander_City,_...     32.0      NaN  NaN
# 7   https://en.wikipedia.org/wiki/Aliceville,_Alabama      NaN      NaN  NaN
# 8      https://en.wikipedia.org/wiki/Allgood,_Alabama      NaN      NaN  NaN
# 9      https://en.wikipedia.org/wiki/Altoona,_Alabama      NaN      NaN  NaN
# 10   https://en.wikipedia.org/wiki/Andalusia,_Alabama      NaN      NaN  NaN
# 11  https://en.wikipedia.org/wiki/Anderson,_Lauder...      NaN      NaN  NaN
# 12    https://en.wikipedia.org/wiki/Anniston,_Alabama     63.0      NaN  NaN
# 13        https://en.wikipedia.org/wiki/Arab,_Alabama     41.0      NaN  NaN
# 14     https://en.wikipedia.org/wiki/Ardmore,_Alabama      NaN      NaN  NaN
# 15        https://en.wikipedia.org/wiki/Argo,_Alabama      NaN      NaN  NaN
# 16      https://en.wikipedia.org/wiki/Ariton,_Alabama      NaN      NaN  NaN
# 17       https://en.wikipedia.org/wiki/Arley,_Alabama      NaN      NaN  NaN
# 18     https://en.wikipedia.org/wiki/Ashford,_Alabama      NaN      NaN  NaN
# 19     https://en.wikipedia.org/wiki/Ashland,_Alabama      NaN      NaN  NaN
#
#               City    State Unnamed: 0_y        rev_id  Prediction
# 0        Abbeville  Alabama          0.0  1.171164e+09           C
# 1       Adamsville  Alabama          1.0  1.177621e+09           C
# 2          Addison  Alabama          2.0  1.168360e+09           C
# 3            Akron  Alabama          3.0  1.165910e+09          GA
# 4        Alabaster  Alabama          4.0  1.179140e+09           C
# 5      Albertville  Alabama          5.0  1.179199e+09           C
# 6   Alexander City  Alabama          6.0  1.179140e+09          GA
# 7       Aliceville  Alabama          7.0  1.167792e+09          GA
# 8          Allgood  Alabama          8.0  1.165910e+09           C
# 9          Altoona  Alabama          9.0  1.165910e+09           C
# 10       Andalusia  Alabama         10.0  1.179142e+09           C
# 11        Anderson  Alabama         11.0  6.626916e+08        Stub
# 12        Anniston  Alabama         12.0  1.176049e+09           C
# 13            Arab  Alabama         13.0  1.171375e+09           C
# 14         Ardmore  Alabama         14.0  1.176903e+09          GA
# 15            Argo  Alabama         15.0  1.177624e+09           C
# 16          Ariton  Alabama         16.0  1.166014e+09           C
# 17           Arley  Alabama         17.0  1.166014e+09           C
# 18         Ashford  Alabama         18.0  1.166015e+09           C
# 19         Ashland  Alabama         19.0  1.174332e+09           C
#
# [20 rows x 22 columns]

# %% [markdown]
# Over here our files from the above join are joined with df_population which has data of state wise population for 2022. A few columns are dropped

# %%
join_2 = pd.merge(join_1, df_population, left_on = join_1['State'],  right_on = df_population['Geographic Area'], 
                  how='left')

# %%
join_2.columns
# Out:
# Index([                       'key_0',                       'pageid',
#                                  'ns',                        'title',
#                        'contentmodel',                 'pagelanguage',
#                'pagelanguagehtmlcode',              'pagelanguagedir',
#                             'touched',                    'lastrevid',
#                              'length',                       'talkid',
#                             'fullurl',                      'editurl',
#                        'canonicalurl',                     'watchers',
#                            'redirect',                          'new',
#                                'City',                        'State',
#                        'Unnamed: 0_y',                       'rev_id',
#                          'Prediction',              'Geographic Area',
#        'April 1, 2020 Estimates Base',                           2020,
#                                  2021,                           2022],
#       dtype='object')

# %%
join_2.drop(['April 1, 2020 Estimates Base', 2020, 2021, 'key_0' , 'Unnamed: 0_y'],
            axis = 1, inplace = True)

# %%
join_2.head()
# Out:
#    pageid  ns                title contentmodel pagelanguage  \
# 0  104730   0   Abbeville, Alabama     wikitext           en
# 1  104761   0  Adamsville, Alabama     wikitext           en
# 2  105188   0     Addison, Alabama     wikitext           en
# 3  104726   0       Akron, Alabama     wikitext           en
# 4  105109   0   Alabaster, Alabama     wikitext           en
#
#   pagelanguagehtmlcode pagelanguagedir               touched   lastrevid  \
# 0                   en             ltr  2023-10-10T22:35:37Z  1171163550
# 1                   en             ltr  2023-10-10T22:35:37Z  1177621427
# 2                   en             ltr  2023-10-10T22:35:37Z  1168359898
# 3                   en             ltr  2023-10-10T22:35:37Z  1165909508
# 4                   en             ltr  2023-10-10T22:35:37Z  1179139816
#
#    length  ...                                       canonicalurl watchers  \
# 0   24706  ...   https://en.wikipedia.org/wiki/Abbeville,_Alabama      NaN
# 1   18040  ...  https://en.wikipedia.org/wiki/Adamsville,_Alabama      NaN
# 2   13309  ...     https://en.wikipedia.org/wiki/Addison,_Alabama      NaN
# 3   11710  ...       https://en.wikipedia.org/wiki/Akron,_Alabama      NaN
# 4   20343  ...   https://en.wikipedia.org/wiki/Alabaster,_Alabama      NaN
#
#   redirect new        City    State        rev_id Prediction Geographic Area  \
# 0      NaN NaN   Abbeville  Alabama  1.171164e+09          C         Alabama
# 1      NaN NaN  Adamsville  Alabama  1.177621e+09          C         Alabama
# 2      NaN NaN     Addison  Alabama  1.168360e+09          C         Alabama
# 3      NaN NaN       Akron  Alabama  1.165910e+09         GA         Alabama
# 4      NaN NaN   Alabaster  Alabama  1.179140e+09          C         Alabama
#
#         2022
# 0  5074296.0
# 1  5074296.0
# 2  5074296.0
# 3  5074296.0
# 4  5074296.0
#
# [5 rows x 23 columns]

# %%
join_2.columns
# Out:
# Index([              'pageid',                   'ns',                'title',
#                'contentmodel',         'pagelanguage', 'pagelanguagehtmlcode',
#             'pagelanguagedir',              'touched',            'lastrevid',
#                      'length',               'talkid',              'fullurl',
#                     'editurl',         'canonicalurl',             'watchers',
#                    'redirect',                  'new',                 'City',
#                       'State',               'rev_id',           'Prediction',
#             'Geographic Area',                   2022],
#       dtype='object')

# %%
join_2.to_csv('join_with_states.csv')

# %%
df_states.head()
# Out:
#       REGION     DIVISION          STATE
# 0  Northeast  New England    Connecticut
# 1  Northeast  New England          Maine
# 2  Northeast  New England  Massachusetts
# 3  Northeast  New England  New Hampshire
# 4  Northeast  New England   Rhode Island

# %% [markdown]
# This is the final join with df_states to get the region and division which we will be using in our final anaylsis

# %%
join_3 = pd.merge(join_2, df_states, left_on = join_2['State'],  right_on = df_states['STATE'], 
                  how='left')

# %%
join_3.head()
# Out:
#      key_0  pageid  ns                title contentmodel pagelanguage  \
# 0  Alabama  104730   0   Abbeville, Alabama     wikitext           en
# 1  Alabama  104761   0  Adamsville, Alabama     wikitext           en
# 2  Alabama  105188   0     Addison, Alabama     wikitext           en
# 3  Alabama  104726   0       Akron, Alabama     wikitext           en
# 4  Alabama  105109   0   Alabaster, Alabama     wikitext           en
#
#   pagelanguagehtmlcode pagelanguagedir               touched   lastrevid  ...  \
# 0                   en             ltr  2023-10-10T22:35:37Z  1171163550  ...
# 1                   en             ltr  2023-10-10T22:35:37Z  1177621427  ...
# 2                   en             ltr  2023-10-10T22:35:37Z  1168359898  ...
# 3                   en             ltr  2023-10-10T22:35:37Z  1165909508  ...
# 4                   en             ltr  2023-10-10T22:35:37Z  1179139816  ...
#
#    new        City    State        rev_id Prediction  Geographic Area  \
# 0  NaN   Abbeville  Alabama  1.171164e+09          C          Alabama
# 1  NaN  Adamsville  Alabama  1.177621e+09          C          Alabama
# 2  NaN     Addison  Alabama  1.168360e+09          C          Alabama
# 3  NaN       Akron  Alabama  1.165910e+09         GA          Alabama
# 4  NaN   Alabaster  Alabama  1.179140e+09          C          Alabama
#
#         2022  REGION            DIVISION    STATE
# 0  5074296.0   South  East South Central  Alabama
# 1  5074296.0   South  East South Central  Alabama
# 2  5074296.0   South  East South Central  Alabama
# 3  5074296.0   South  East South Central  Alabama
# 4  5074296.0   South  East South Central  Alabama
#
# [5 rows x 27 columns]

# %%
join_3.columns
# Out:
# Index([               'key_0',               'pageid',                   'ns',
#                       'title',         'contentmodel',         'pagelanguage',
#        'pagelanguagehtmlcode',      'pagelanguagedir',              'touched',
#                   'lastrevid',               'length',               'talkid',
#                     'fullurl',              'editurl',         'canonicalurl',
#                    'watchers',             'redirect',                  'new',
#                        'City',                'State',               'rev_id',
#                  'Prediction',      'Geographic Area',                   2022,
#                      'REGION',             'DIVISION',                'STATE'],
#       dtype='object')

# %%
join_3.columns
# Out:
# Index([               'key_0',               'pageid',                   'ns',
#                       'title',         'contentmodel',         'pagelanguage',
#        'pagelanguagehtmlcode',      'pagelanguagedir',              'touched',
#                   'lastrevid',               'length',               'talkid',
#                     'fullurl',              'editurl',         'canonicalurl',
#                    'watchers',             'redirect',                  'new',
#                        'City',                'State',               'rev_id',
#                  'Prediction',      'Geographic Area',                   2022,
#                      'REGION',             'DIVISION',                'STATE'],
#       dtype='object')

# %% [markdown]
# ALL IRRELEVANT COLUMNS ARE NOW DROPPED TO BRING OUR TABLE TO DESIRED FORMAT. ANY MISSING VALUES ARE ALSO DROPPED

# %%
join_3.drop(['pageid', 'ns', 'touched', 'length', 'talkid', 'fullurl', 'editurl', 'canonicalurl', 
             'watchers', 'redirect', 'new', 'City', 'lastrevid', 'Geographic Area', 'STATE', 'REGION', 'key_0',
            'contentmodel', 'pagelanguage', 'pagelanguagehtmlcode', 'pagelanguagedir'], 
            axis = 1, inplace = True)

# %%
join_3.head()
# Out:
#                  title    State        rev_id Prediction       2022  \
# 0   Abbeville, Alabama  Alabama  1.171164e+09          C  5074296.0
# 1  Adamsville, Alabama  Alabama  1.177621e+09          C  5074296.0
# 2     Addison, Alabama  Alabama  1.168360e+09          C  5074296.0
# 3       Akron, Alabama  Alabama  1.165910e+09         GA  5074296.0
# 4   Alabaster, Alabama  Alabama  1.179140e+09          C  5074296.0
#
#              DIVISION
# 0  East South Central
# 1  East South Central
# 2  East South Central
# 3  East South Central
# 4  East South Central

# %%
final_df = join_3.dropna()

# %%
##Rows with missing values 
print(f'rows with missing values are: {join_3.shape[0] - final_df.shape[0]}')
# Out:
# rows with missing values are: 4942

# %%
final_df = final_df.rename(columns={2022: 'population'})

# %%
final_df.to_csv('wp_scored_city_articles_by_state.csv')
